# %% [markdown]
# # Random Forest
# ## Table of Contents
# * [Bibliotecas](#Bibliotecas-(Libraries))
# * [Leitura dos Dados](#Leitura-dos-Dados)
# * [Buscando os Melhores Hiperparâmetros](#Buscando-os-Melhores-Hiperparâmetros)
# * [Florestas Aleatórias](#Florestas-Aleatórias)
# * [Análise de Erro](#Análise-de-Erro)
# * [Retreinando o Modelo](#Retreinando-o-Modelo)
# * [Criando o Resultado](#Criando-o-Resultado-das-Previsões-para-Importar-ao-Kaggle)

# %% [markdown]
# ## Bibliotecas (Libraries)

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RepeatedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from skopt import gp_minimize

# %% [markdown]
# ## Leitura dos Dados
# Lendo o training e o test set, e conferindo as suas dimensões.

# %%
X_train_pre, X_test = pd.read_csv('../data/preprocessed/train.csv'), pd.read_csv('../data/preprocessed/test.csv')
print(f'Train set shape: {X_train_pre.shape}\nTest set shape: {X_test.shape}')
# Out:
# Train set shape: (891, 29)
# Test set shape: (418, 28)

# %% [markdown]
# Lendo os 5 primeiros exemplos do training set.

# %%
X_train_pre.head()
# Out:
#    Sex_b  Age_pre  Pclass  Embarked_S  Embarked_C  SibSp  Parch     Fare  \
# 0      0     22.0       3           1           0      1      0   7.2500
# 1      1     38.0       1           0           1      1      0  71.2833
# 2      1     26.0       3           1           0      0      0   7.9250
# 3      1     35.0       1           1           0      1      0  53.1000
# 4      0     35.0       3           1           0      0      0   8.0500
#
#    Cabin_null  Cabin_C  ...  Name_Master  Name_Col  Name_Major  Name_Mr  \
# 0           1        0  ...            0         0           0        1
# 1           0        1  ...            0         0           0        1
# 2           1        0  ...            0         0           0        0
# 3           0        1  ...            0         0           0        1
# 4           1        0  ...            0         0           0        1
#
#    Name_Dr  Name_Don  Name_Sir  Ticket_num  Ticket_cat  Survived
# 0        0         0         0       21171           0         0
# 1        0         0         0       17599           1         1
# 2        0         0         0     3101282           2         1
# 3        0         0         0      113803           3         1
# 4        0         0         0      373450           4         0
#
# [5 rows x 29 columns]

# %% [markdown]
# Separando as features $X$ e o target $y$ para a criação do modelo.

# %%
y = X_train_pre['Survived'].copy()
X = X_train_pre.drop(columns=['Survived'], axis=1).copy()

# %% [markdown]
# ## Buscando os Melhores Hiperparâmetros
# Utilizando o método bayesian optimization para buscar os melhores hiperparâmetros para o modelo.

# %%
def fit_model(hparams):    
    model = RandomForestClassifier(
        n_estimators=hparams[0],
        max_depth=hparams[1],
        min_samples_split=hparams[2],
        n_jobs=-1,
        random_state=42
    )
    model.fit(X_opt, y)
    
    yhat_train = model.predict(X_opt)
    
    return -accuracy_score(yhat_train, y)

# %% [markdown]
# Definindo o espaço de cada hiperparâmetro para o modelo avaliar o desempenho do modelo em cada espaço de cada hiperparâmetro e retornando a melhor combinação, então, depois escalamos os dados, executamos a otimização dos hiperparâmetros e visualizamos a melhor combinação dos hiperparâmetros.

# %%
space = [
    (100, 500), # n_estimators
    (250, 500), # max_depth
    (2, 25), # min_samples_split
]

X_opt = StandardScaler().fit_transform(X)
opt = gp_minimize(fit_model, space, random_state=42, verbose=0, n_calls=50, n_random_starts=20)
opt.x
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# [np.int64(347), np.int64(403), np.int64(2)]

# %% [markdown]
# ## Random Forest
# Criando, treinando o modelo no fold do training set e avaliando o modelo nos folds de training e dev set.
#
# As avaliações no training e dev set estão sendo adicionadas em uma lista para depois serem plotadas.

# %%
kf = RepeatedKFold(n_splits=2, n_repeats=10, random_state=42)

scaler = StandardScaler()

step_train = []
step_cv = []
i = 0

for linhas_train, linhas_cv in kf.split(X):
    X_train, X_cv = X.iloc[linhas_train].copy(), X.iloc[linhas_cv].copy()
    y_train, y_cv = y.iloc[linhas_train].copy(), y.iloc[linhas_cv].copy()
    
    X_train = scaler.fit_transform(X_train)
    X_cv = scaler.transform(X_cv)

    model = RandomForestClassifier(
        n_estimators=200, 
        n_jobs=-1,
        random_state=42,
        max_depth=3,
        min_samples_split=5
    )
    model.fit(X_train, y_train)

    yhat_train = model.predict(X_train)
    yhat_cv = model.predict(X_cv)

    acc_train = np.mean(y_train == yhat_train)
    acc_cv = np.mean(y_cv == yhat_cv)

    if i % 10 == 0:
        print(f'acc_train: {acc_train:.4f}, acc_cv: {acc_cv:.4f}\n')

    step_train.append(acc_train)
    step_cv.append(acc_cv)
    i += 1

print(f'{"=" * 35}\n\nTrain mean: {np.mean(step_train):.2f}, CV mean: {np.mean(step_cv):.2f}')
# Out:
# acc_train: 0.8472, acc_cv: 0.7982
#
# acc_train: 0.8315, acc_cv: 0.7892
#
# ===================================
#
# Train mean: 0.83, CV mean: 0.80

# %% [markdown]
# Plotando o histórico do desempenho no training e no dev set.

# %%
plt.hist(step_train, label='Train')
plt.hist(step_cv, label='Validation', alpha=.75)
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Acurácia', fontsize=16)
plt.legend(loc='best', fontsize=16)
plt.grid(False)
plt.show()

# %% [markdown]
# Realizando a predição no test set.

# %%
X_test_pre = scaler.transform(X_test)
yhat = model.predict(X_test_pre)

# %% [markdown]
# ## Análise de Erro
# Executando a análise de erro nas previsões.

# %%
train = pd.read_csv('../data/raw/train.csv')
features = [c for c in X_train_pre.columns if c not in train.columns]
train = pd.concat([train, X_train_pre[features]], axis=1)

X_cv_erro = train.loc[linhas_cv].copy()
X_cv_erro['yhat'] = yhat_cv
X_cv_erro.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 6             7         0       1
# 8             9         1       3
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare  ... Name_Master Name_Col  Name_Major  Name_Mr  \
# 1       0  PC 17599  71.2833  ...           0        0           0        1
# 6       0     17463  51.8625  ...           0        0           0        1
# 8       2    347742  11.1333  ...           0        0           0        1
# 10      1   PP 9549  16.7000  ...           0        0           0        0
# 11      0    113783  26.5500  ...           0        0           0        0
#
#     Name_Dr  Name_Don  Name_Sir  Ticket_num  Ticket_cat  yhat
# 1         0         0         0       17599           1     1
# 6         0         0         0       17463           6     0
# 8         0         0         0      347742           8     0
# 10        0         0         0        9549          10     1
# 11        0         0         0      113783          11     1
#
# [5 rows x 37 columns]

# %% [markdown]
# Definindo as previsões incorretas e, definindo e ordenando as features para leitura do dataset.

# %%
erro = X_cv_erro[X_cv_erro['Survived'] != X_cv_erro['yhat']]
erro = erro[['Survived', 'yhat', 'Name', 'Cabin', 'Embarked', 'Sex', 'Sex_b', 'Age', 'Age_pre', 'Pclass', 'Embarked_S',
             'Embarked_C', 'SibSp', 'Parch', 'Fare', 'Cabin_null',
             'Cabin_C', 'Cabin_E', 'Cabin_G', 'Cabin_D', 'Cabin_A', 'Cabin_B', 'Cabin_F', 'Cabin_T',
             'Name_Miss', 'Name_Mrs', 'Name_Master', 'Name_Col', 'Name_Major', 'Name_Mr', 'Name_Dr', 'Name_Don', 'Name_Sir']]
erro.head()
# Out:
#     Survived  yhat                                               Name Cabin  \
# 8          1     0  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   NaN
# 17         1     0                       Williams, Mr. Charles Eugene   NaN
# 18         0     1  Vander Planke, Mrs. Julius (Emelia Maria Vande...   NaN
# 23         1     0                       Sloper, Mr. William Thompson    A6
# 25         1     0  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...   NaN
#
#    Embarked     Sex  Sex_b   Age  Age_pre  Pclass  ...  Cabin_T  Name_Miss  \
# 8         S  female      1  27.0     27.0       3  ...        0          0
# 17        S    male      0   NaN     29.0       2  ...        0          0
# 18        S  female      1  31.0     31.0       3  ...        0          0
# 23        S    male      0  28.0     28.0       1  ...        0          0
# 25        S  female      1  38.0     38.0       3  ...        0          0
#
#     Name_Mrs  Name_Master  Name_Col  Name_Major  Name_Mr  Name_Dr  Name_Don  \
# 8          1            0         0           0        1        0         0
# 17         0            0         0           0        1        0         0
# 18         1            0         0           0        1        0         0
# 23         0            0         0           0        1        0         0
# 25         1            0         0           0        1        0         0
#
#     Name_Sir
# 8          0
# 17         0
# 18         0
# 23         0
# 25         0
#
# [5 rows x 33 columns]

# %% [markdown]
# Separando os erros entre a classe `male` e `female`.

# %%
female = erro[erro['Sex_b'] == 1]
male = erro[erro['Sex_b'] == 0]

# %% [markdown]
# Ordenando os erros da classe `female` pelo target $y$.

# %%
female.sort_values('Survived')
# Out:
#      Survived  yhat                                               Name Cabin  \
# 396         0     1                                Olsson, Miss. Elina   NaN
# 404         0     1                            Oreskovic, Miss. Marija   NaN
# 415         0     1            Meek, Mrs. Thomas (Annie Louise Rowley)   NaN
# 423         0     1  Danbom, Mrs. Ernst Gilbert (Anna Sigrid Maria ...   NaN
# 436         0     1               Ford, Miss. Doolina Margaret "Daisy"   NaN
# 501         0     1                                Canavan, Miss. Mary   NaN
# 502         0     1                     O'Sullivan, Miss. Bridget Mary   NaN
# 564         0     1                     Meanwell, Miss. (Marion Ogden)   NaN
# 578         0     1                   Caram, Mrs. Joseph (Maria Elias)   NaN
# 593         0     1                                 Bourke, Miss. Mary   NaN
# 657         0     1                      Bourke, Mrs. John (Catherine)   NaN
# 767         0     1                                 Mangan, Miss. Mary   NaN
# 772         0     1                                  Mack, Mrs. (Mary)   E77
# 792         0     1                            Sage, Miss. Stella Anna   NaN
# 799         0     1  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...   NaN
# 816         0     1                       Heininen, Miss. Wendla Maria   NaN
# 854         0     1      Carter, Mrs. Ernest Courtenay (Lilian Hughes)   NaN
# 863         0     1                  Sage, Miss. Dorothy Edith "Dolly"   NaN
# 402         0     1                           Jussila, Miss. Mari Aina   NaN
# 882         0     1                       Dahlberg, Miss. Gerda Ulrika   NaN
# 888         0     1           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 276         0     1                  Lindblom, Miss. Augusta Charlotta   NaN
# 18          0     1  Vander Planke, Mrs. Julius (Emelia Maria Vande...   NaN
# 49          0     1      Arnold-Franchi, Mrs. Josef (Josefine Franchi)   NaN
# 71          0     1                         Goodwin, Miss. Lillian Amy   NaN
# 100         0     1                            Petranec, Miss. Matilda   NaN
# 111         0     1                               Zabour, Miss. Hileni   NaN
# 312         0     1              Lahtinen, Mrs. William (Anna Sylfven)   NaN
# 114         0     1                              Attalah, Miss. Malake   NaN
# 132         0     1     Robins, Mrs. Alexander A (Grace Charity Laury)   NaN
# 113         0     1                            Jussila, Miss. Katriina   NaN
# 177         0     1                         Isham, Miss. Ann Elizabeth   C49
# 180         0     1                       Sage, Miss. Constance Gladys   NaN
# 199         0     1             Yrois, Miss. Henriette ("Mrs Harbeck")   NaN
# 235         0     1                       Harknett, Miss. Alice Phoebe   NaN
# 240         0     1                              Zabour, Miss. Thamine   NaN
# 254         0     1           Rosblom, Mrs. Viktor (Helena Wilhelmina)   NaN
# 140         0     1                      Boulos, Mrs. Joseph (Sultana)   NaN
# 233         1     0                     Asplund, Miss. Lillian Gertrud   NaN
# 797         1     0                                   Osman, Mrs. Mara   NaN
# 68          1     0                    Andersson, Miss. Erna Alexandra   NaN
# 25          1     0  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...   NaN
# 855         1     0                         Aks, Mrs. Sam (Leah Rosen)   NaN
# 8           1     0  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   NaN
#
#     Embarked     Sex  Sex_b   Age  Age_pre  Pclass  ...  Cabin_T  Name_Miss  \
# 396        S  female      1  31.0     31.0       3  ...        0          1
# 404        S  female      1  20.0     20.0       3  ...        0          1
# 415        S  female      1   NaN     29.0       3  ...        0          0
# 423        S  female      1  28.0     28.0       3  ...        0          0
# 436        S  female      1  21.0     21.0       3  ...        0          1
# 501        Q  female      1  21.0     21.0       3  ...        0          1
# 502        Q  female      1   NaN     29.0       3  ...        0          1
# 564        S  female      1   NaN     29.0       3  ...        0          1
# 578        C  female      1   NaN     29.0       3  ...        0          0
# 593        Q  female      1   NaN     29.0       3  ...        0          1
# 657        Q  female      1  32.0     32.0       3  ...        0          0
# 767        Q  female      1  30.5     30.5       3  ...        0          1
# 772        S  female      1  57.0     57.0       2  ...        0          0
# 792        S  female      1   NaN     29.0       3  ...        0          1
# 799        S  female      1  30.0     30.0       3  ...        0          0
# 816        S  female      1  23.0     23.0       3  ...        0          1
# 854        S  female      1  44.0     44.0       2  ...        0          0
# 863        S  female      1   NaN     29.0       3  ...        0          1
# 402        S  female      1  21.0     21.0       3  ...        0          1
# 882        S  female      1  22.0     22.0       3  ...        0          1
# 888        S  female      1   NaN     29.0       3  ...        0          1
# 276        S  female      1  45.0     45.0       3  ...        0          1
# 18         S  female      1  31.0     31.0       3  ...        0          0
# 49         S  female      1  18.0     18.0       3  ...        0          0
# 71         S  female      1  16.0     16.0       3  ...        0          1
# 100        S  female      1  28.0     28.0       3  ...        0          1
# 111        C  female      1  14.5     14.5       3  ...        0          1
# 312        S  female      1  26.0     26.0       2  ...        0          0
# 114        C  female      1  17.0     17.0       3  ...        0          1
# 132        S  female      1  47.0     47.0       3  ...        0          0
# 113        S  female      1  20.0     20.0       3  ...        0          1
# 177        C  female      1  50.0     50.0       1  ...        0          1
# 180        S  female      1   NaN     29.0       3  ...        0          1
# 199        S  female      1  24.0     24.0       2  ...        0          1
# 235        S  female      1   NaN     29.0       3  ...        0          1
# 240        C  female      1   NaN     29.0       3  ...        0          1
# 254        S  female      1  41.0     41.0       3  ...        0          0
# 140        C  female      1   NaN     29.0       3  ...        0          0
# 233        S  female      1   5.0      5.0       3  ...        0          1
# 797        S  female      1  31.0     31.0       3  ...        0          0
# 68         S  female      1  17.0     17.0       3  ...        0          1
# 25         S  female      1  38.0     38.0       3  ...        0          0
# 855        S  female      1  18.0     18.0       3  ...        0          0
# 8          S  female      1  27.0     27.0       3  ...        0          0
#
#      Name_Mrs  Name_Master  Name_Col  Name_Major  Name_Mr  Name_Dr  Name_Don  \
# 396         0            0         0           0        0        0         0
# 404         0            0         0           0        0        0         0
# 415         1            0         0           0        1        0         0
# 423         1            0         0           0        1        0         0
# 436         0            0         0           0        0        0         0
# 501         0            0         0           0        0        0         0
# 502         0            0         0           0        0        0         0
# 564         0            0         0           0        0        0         0
# 578         1            0         0           0        1        0         0
# 593         0            0         0           0        0        0         0
# 657         1            0         0           0        1        0         0
# 767         0            0         0           0        0        0         0
# 772         1            0         0           0        1        0         0
# 792         0            0         0           0        0        0         0
# 799         1            0         0           0        1        0         0
# 816         0            0         0           0        0        0         0
# 854         1            0         0           0        1        0         0
# 863         0            0         0           0        0        0         0
# 402         0            0         0           0        0        0         0
# 882         0            0         0           0        0        0         0
# 888         0            0         0           0        0        0         0
# 276         0            0         0           0        0        0         0
# 18          1            0         0           0        1        0         0
# 49          1            0         0           0        1        0         0
# 71          0            0         0           0        0        0         0
# 100         0            0         0           0        0        0         0
# 111         0            0         0           0        0        0         0
# 312         1            0         0           0        1        0         0
# 114         0            0         0           0        0        0         0
# 132         1            0         0           0        1        0         0
# 113         0            0         0           0        0        0         0
# 177         0            0         0           0        0        0         0
# 180         0            0         0           0        0        0         0
# 199         1            0         0           0        1        0         0
# 235         0            0         0           0        0        0         0
# 240         0            0         0           0        0        0         0
# 254         1            0         0           0        1        0         0
# 140         1            0         0           0        1        0         0
# 233         0            0         0           0        0        0         0
# 797         1            0         0           0        1        0         0
# 68          0            0         0           0        0        0         0
# 25          1            0         0           0        1        0         0
# 855         1            0         0           0        1        0         0
# 8           1            0         0           0        1        0         0
#
#      Name_Sir
# 396         0
# 404         0
# 415         0
# 423         0
# 436         0
# 501         0
# 502         0
# 564         0
# 578         0
# 593         0
# 657         0
# 767         0
# 772         0
# 792         0
# 799         0
# 816         0
# 854         0
# 863         0
# 402         0
# 882         0
# 888         0
# 276         0
# 18          0
# 49          0
# 71          0
# 100         0
# 111         0
# 312         0
# 114         0
# 132         0
# 113         0
# 177         0
# 180         0
# 199         0
# 235         0
# 240         0
# 254         0
# 140         0
# 233         0
# 797         0
# 68          0
# 25          0
# 855         0
# 8           0
#
# [44 rows x 33 columns]

# %% [markdown]
# Ordenando os erros da classe `male` pelo target $y$.

# %%
male.sort_values('Survived')
# Out:
#      Survived  yhat                                             Name    Cabin  \
# 245         0     1                      Minahan, Dr. William Edward      C78
# 17          1     0                     Williams, Mr. Charles Eugene      NaN
# 553         1     0                Leeni, Mr. Fahim ("Philip Zenni")      NaN
# 569         1     0                                Jonsson, Mr. Carl      NaN
# 579         1     0                              Jussila, Mr. Eiriik      NaN
# 599         1     0     Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")      A20
# 621         1     0                     Kimball, Mr. Edwin Nelson Jr      D19
# 645         1     0                        Harper, Mr. Henry Sleeper      D33
# 664         1     0                      Lindqvist, Mr. Eino William      NaN
# 681         1     0                               Hassab, Mr. Hammad      D49
# 690         1     0                          Dick, Mr. Albert Adrian      B20
# 692         1     0                                     Lam, Mr. Ali      NaN
# 701         1     0                 Silverthorne, Mr. Spencer Victor      E24
# 707         1     0                Calderhead, Mr. Edward Pennington      E24
# 724         1     0                    Chambers, Mr. Norman Campbell       E8
# 737         1     0                           Lesurer, Mr. Gustave J     B101
# 740         1     0                      Hawksford, Mr. Walter James      D45
# 744         1     0                               Stranden, Mr. Juho      NaN
# 751         1     0                              Moor, Master. Meier     E121
# 755         1     0                        Hamalainen, Master. Viljo      NaN
# 788         1     0                       Dean, Master. Bertram Vere      NaN
# 803         1     0                  Thomas, Master. Assad Alexander      NaN
# 804         1     0                          Hedman, Mr. Oskar Arvid      NaN
# 828         1     0                     McCormack, Mr. Thomas Joseph      NaN
# 550         1     0                      Thayer, Mr. John Borland Jr      C70
# 512         1     0                        McGough, Mr. James Robert      E25
# 507         1     0    Bradley, Mr. George ("George Arthur Brayton")      NaN
# 460         1     0                              Anderson, Mr. Harry      E12
# 23          1     0                     Sloper, Mr. William Thompson       A6
# 74          1     0                                    Bing, Mr. Lee      NaN
# 78          1     0                    Caldwell, Master. Alden Gates      NaN
# 81          1     0                      Sheerlinck, Mr. Jan Baptist      NaN
# 97          1     0                  Greenfield, Mr. William Bertram  D10 D12
# 125         1     0                     Nicola-Yarred, Master. Elias      NaN
# 165         1     0  Goldsmith, Master. Frank John William "Frankie"      NaN
# 187         1     0    Romaine, Mr. Charles Hallace ("Mr C Rolmane")      NaN
# 204         1     0                         Cohen, Mr. Gurshon "Gus"      NaN
# 207         1     0                      Albimona, Mr. Nassef Cassem      NaN
# 209         1     0                                 Blank, Mr. Henry      A31
# 226         1     0                        Mellors, Mr. William John      NaN
# 271         1     0                     Tornquist, Mr. William Henry      NaN
# 288         1     0                             Hosono, Mr. Masabumi      NaN
# 298         1     0                            Saalfeld, Mr. Adolphe     C106
# 301         1     0                               McCoy, Mr. Bernard      NaN
# 370         1     0                      Harder, Mr. George Achilles      E50
# 400         1     0                               Niskanen, Mr. Juha      NaN
# 414         1     0                        Sundman, Mr. Johan Julian      NaN
# 429         1     0               Pickard, Mr. Berk (Berk Trembisky)      E10
# 444         1     0                Johannesen-Bratthammer, Mr. Bernt      NaN
# 449         1     0                   Peuchen, Major. Arthur Godfrey     C104
# 453         1     0                         Goldenberg, Mr. Samuel L      C92
# 857         1     0                           Daly, Mr. Peter Denis       E17
# 869         1     0                  Johnson, Master. Harold Theodor      NaN
#
#     Embarked   Sex  Sex_b    Age  Age_pre  Pclass  ...  Cabin_T  Name_Miss  \
# 245        Q  male      0  44.00    44.00       1  ...        0          0
# 17         S  male      0    NaN    29.00       2  ...        0          0
# 553        C  male      0  22.00    22.00       3  ...        0          0
# 569        S  male      0  32.00    32.00       3  ...        0          0
# 579        S  male      0  32.00    32.00       3  ...        0          0
# 599        C  male      0  49.00    49.00       1  ...        0          0
# 621        S  male      0  42.00    42.00       1  ...        0          0
# 645        C  male      0  48.00    48.00       1  ...        0          0
# 664        S  male      0  20.00    20.00       3  ...        0          0
# 681        C  male      0  27.00    27.00       1  ...        0          0
# 690        S  male      0  31.00    31.00       1  ...        0          0
# 692        S  male      0    NaN    29.00       3  ...        0          0
# 701        S  male      0  35.00    35.00       1  ...        0          0
# 707        S  male      0  42.00    42.00       1  ...        0          0
# 724        S  male      0  27.00    27.00       1  ...        0          0
# 737        C  male      0  35.00    35.00       1  ...        0          0
# 740        S  male      0    NaN    29.00       1  ...        0          0
# 744        S  male      0  31.00    31.00       3  ...        0          0
# 751        S  male      0   6.00     6.00       3  ...        0          0
# 755        S  male      0   0.67     0.67       2  ...        0          0
# 788        S  male      0   1.00     1.00       3  ...        0          0
# 803        C  male      0   0.42     0.42       3  ...        0          0
# 804        S  male      0  27.00    27.00       3  ...        0          0
# 828        Q  male      0    NaN    29.00       3  ...        0          0
# 550        C  male      0  17.00    17.00       1  ...        0          0
# 512        S  male      0  36.00    36.00       1  ...        0          0
# 507        S  male      0    NaN    29.00       1  ...        0          0
# 460        S  male      0  48.00    48.00       1  ...        0          0
# 23         S  male      0  28.00    28.00       1  ...        0          0
# 74         S  male      0  32.00    32.00       3  ...        0          0
# 78         S  male      0   0.83     0.83       2  ...        0          0
# 81         S  male      0  29.00    29.00       3  ...        0          0
# 97         C  male      0  23.00    23.00       1  ...        0          0
# 125        C  male      0  12.00    12.00       3  ...        0          0
# 165        S  male      0   9.00     9.00       3  ...        0          0
# 187        S  male      0  45.00    45.00       1  ...        0          0
# 204        S  male      0  18.00    18.00       3  ...        0          0
# 207        C  male      0  26.00    26.00       3  ...        0          0
# 209        C  male      0  40.00    40.00       1  ...        0          0
# 226        S  male      0  19.00    19.00       2  ...        0          0
# 271        S  male      0  25.00    25.00       3  ...        0          0
# 288        S  male      0  42.00    42.00       2  ...        0          0
# 298        S  male      0    NaN    29.00       1  ...        0          0
# 301        Q  male      0    NaN    29.00       3  ...        0          0
# 370        C  male      0  25.00    25.00       1  ...        0          0
# 400        S  male      0  39.00    39.00       3  ...        0          0
# 414        S  male      0  44.00    44.00       3  ...        0          0
# 429        S  male      0  32.00    32.00       3  ...        0          0
# 444        S  male      0    NaN    29.00       3  ...        0          0
# 449        S  male      0  52.00    52.00       1  ...        0          0
# 453        C  male      0  49.00    49.00       1  ...        0          0
# 857        S  male      0  51.00    51.00       1  ...        0          0
# 869        S  male      0   4.00     4.00       3  ...        0          0
#
#      Name_Mrs  Name_Master  Name_Col  Name_Major  Name_Mr  Name_Dr  Name_Don  \
# 245         0            0         0           0        0        1         0
# 17          0            0         0           0        1        0         0
# 553         0            0         0           0        1        0         0
# 569         0            0         0           0        1        0         0
# 579         0            0         0           0        1        0         0
# 599         0            0         0           0        1        0         0
# 621         0            0         0           0        1        0         0
# 645         0            0         0           0        1        0         0
# 664         0            0         0           0        1        0         0
# 681         0            0         0           0        1        0         0
# 690         0            0         0           0        1        0         0
# 692         0            0         0           0        1        0         0
# 701         0            0         0           0        1        0         0
# 707         0            0         0           0        1        0         0
# 724         0            0         0           0        1        0         0
# 737         0            0         0           0        1        0         0
# 740         0            0         0           0        1        0         0
# 744         0            0         0           0        1        0         0
# 751         0            1         0           0        0        0         0
# 755         0            1         0           0        0        0         0
# 788         0            1         0           0        0        0         0
# 803         0            1         0           0        0        0         0
# 804         0            0         0           0        1        0         0
# 828         0            0         0           0        1        0         0
# 550         0            0         0           0        1        0         0
# 512         0            0         0           0        1        0         0
# 507         0            0         0           0        1        0         0
# 460         0            0         0           0        1        0         0
# 23          0            0         0           0        1        0         0
# 74          0            0         0           0        1        0         0
# 78          0            1         0           0        0        0         0
# 81          0            0         0           0        1        0         0
# 97          0            0         0           0        1        0         0
# 125         0            1         0           0        0        0         0
# 165         0            1         0           0        0        0         0
# 187         0            0         0           0        1        0         0
# 204         0            0         0           0        1        0         0
# 207         0            0         0           0        1        0         0
# 209         0            0         0           0        1        0         0
# 226         0            0         0           0        1        0         0
# 271         0            0         0           0        1        0         0
# 288         0            0         0           0        1        0         0
# 298         0            0         0           0        1        0         0
# 301         0            0         0           0        1        0         0
# 370         0            0         0           0        1        0         0
# 400         0            0         0           0        1        0         0
# 414         0            0         0           0        1        0         0
# 429         0            0         0           0        1        0         0
# 444         0            0         0           0        1        0         0
# 449         0            0         0           1        0        0         0
# 453         0            0         0           0        1        0         0
# 857         0            0         0           0        1        0         0
# 869         0            1         0           0        0        0         0
#
#      Name_Sir
# 245         0
# 17          0
# 553         0
# 569         0
# 579         0
# 599         1
# 621         0
# 645         0
# 664         0
# 681         0
# 690         0
# 692         0
# 701         0
# 707         0
# 724         0
# 737         0
# 740         0
# 744         0
# 751         0
# 755         0
# 788         0
# 803         0
# 804         0
# 828         0
# 550         0
# 512         0
# 507         0
# 460         0
# 23          0
# 74          0
# 78          0
# 81          0
# 97          0
# 125         0
# 165         0
# 187         0
# 204         0
# 207         0
# 209         0
# 226         0
# 271         0
# 288         0
# 298         0
# 301         0
# 370         0
# 400         0
# 414         0
# 429         0
# 444         0
# 449         0
# 453         0
# 857         0
# 869         0
#
# [53 rows x 33 columns]

# %% [markdown]
# ## Criando o Resultado das Previsões para Importar ao Kaggle
# Criando o dataset com as previsões finais do test set.

# %%
test = pd.read_csv('../data/raw/test.csv')

result = pd.Series(yhat, index=test['PassengerId'], name='Survived')
result
# Out:
# PassengerId
# 892     0
# 893     0
# 894     0
# 895     0
# 896     1
#        ..
# 1305    0
# 1306    1
# 1307    0
# 1308    0
# 1309    0
# Name: Survived, Length: 418, dtype: int64

# %% [markdown]
# Exportando o dataset com as previsões finais do test set.

# %%
result.to_csv('../yhat/random_forest.csv', header=True)
